# %% [markdown]
# # <center> Trabajo Practico N1: Redes Convolucionales </center>
# <div>
# <img src="attachment:image-4.png" width="500"/>
# </div>
#
# ### <center>José Mornaghi y Lucas Argento</center>

# %% [markdown]
# > ##  Introducción
#
#
# Con el objetivo de estudiar las redes neuronales convolucionales, sus aplicaciones y su diseño, se analizó un dataset público sobre imagenes MRI de pacientes con distintos grados de la enfermedad de Alzheimer. El objetivo del estudio fue clasificar las imagenes de entrada en 4 clases distintas, cada una indicando un distinto grado de avance de la enfermedad.
#
# Para esto, se utilizó una red neuronal convolucional, para la cual se estudiaron diferentes decisiones de diseño y valores de sus hiperparamétros.

# %% [markdown]
# > ## Sobre los datos
#
# El dataset público "Alzheimer MRI Preprocessed Dataset", disponible en Kaggle, contiene imágenes de 4 clases diferentes en tamaños de 128 x 128 pixeles.
#
# Los datos fueron recolectados de diferentes paginas web, hospitales y repositoros públicos. Consisten en imagánes preprocesdad de resonancias magneticas MRI (por sus siglas en inglés Magnetic Resonance Imaging)
#
# El dataset consiste en un total de 6400 imágenes, pertenecientes a una de las siguientes clases:
# Clase - 1: Mild Demented (896 imágenes)
# Clase - 2: Moderate Demented (64 imágenes)
# Clase - 3: Non Demented (3200 imágenes)
# Clase - 4: Very Mild Demented (2240 imágenes)
#
# Elegimos este dataset en particular ya que consideramos que las CNNs tienen un potencial genuino para resolver este tipo de problemas en la vida real, agregando valor y mejorando la vida de las personas.
#
# Referencias:
#
# * https://adni.loni.usc.edu/
# * https://www.alzheimers.net/
# * https://www.kaggle.com/datasets/jboysen/mri-and-alzheimers
# * https://ieeexplore.ieee.org/document/9521165
# * https://catalog.data.gov/dataset/alzheimers-disease-and-healthy-aging-data
# * https://www.nature.com/articles/s41598-020-79243-9
# * https://cordis.europa.eu/article/id/429468-the-final-epad-dataset-is-now-available-on-the-alzheimer-s-disease-workbench

# %% [markdown]
# > ## Librerias a utilizar

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.cuda

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

from utils import train_model, compute_confusion_matrix

from plot_utils import plot_training_loss, plot_accuracy, show_examples, plot_confusion_matrix

# %% [markdown]
# > _Split folders es un paquete que facilita el proceso de hacer un test-train-split con carpetas de imágenes_

# %%
#!pip install split-folders
import splitfolders
splitfolders.ratio('Dataset', output="output", seed=1345, ratio=(.8, 0.1,0.1))
# Out:
# Copying files: 6400 files [00:03, 2111.70 files/s]

# %% [markdown]
# > ## Carga de los datos y separación en sets de entrenamiento, validación y testeo

# %%
NUM_EPOCAS = 3
valid_size = 0.2
batch_size = 1

# %%
# Como se menciono antes, nuestro dataset contiene imagenes en 128x128
IMG_HEIGHT = 128
IMG_WIDTH = 128

# Transformamos a tensores para poder procesar las imagenes con PyTorch
transform = transforms.ToTensor()

# Transformaciones y loadding
train_data = datasets.ImageFolder(root='output/train',transform=transform)
test_data = datasets.ImageFolder(root='output/test',transform=transform)
val_data = datasets.ImageFolder(root='output/val',transform=transform)

# Cargamos en PyTorch
train_loader = torch.utils.data.DataLoader(train_data,
                                           batch_size=batch_size,
                                           num_workers=0)

valid_loader = torch.utils.data.DataLoader(val_data,
                                           batch_size=batch_size,
                                           num_workers=0)

test_loader = torch.utils.data.DataLoader(test_data,
                                          batch_size=batch_size,
                                          num_workers=0)

# %% [markdown]
# > ## Visualizacion de las clases

# %%
class_names = ['Mild_Demented', 'Moderate_Demented', 'Non_Demented', 'Very_Mild_Demented']

# %%
img = next(iter(train_loader))[0][1]
plt.imshow(transforms.ToPILImage()(img))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [10], in <module>
# ----> 1 img = next(iter(train_loader))[0][1]
#       2 plt.imshow(transforms.ToPILImage()(img))
#
# IndexError: index 1 is out of bounds for dimension 0 with size 1

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_data:
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[i])
        plt.axis("off")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [11], in <module>
#       3 for i in range(9):
#       4     ax = plt.subplot(3, 3, i + 1)
# ----> 5     plt.imshow(images[i].numpy().astype("uint8"))
#       6     plt.title(class_names[i])
#       7     plt.axis("off")
#
# IndexError: index 3 is out of bounds for dimension 0 with size 3

# %% [markdown]
# > ## Arquitectura Propuesta
#
# Para el estudio de las CNNs, decidimos partir de la arquitectura original de la Red Neuronal **LeNet** (1998), la cual luego modificaremos para estudiar los efectos de las distintas decisiones de diseño.
# A continuacion, se observa un esquema de la arquitectura original, compuesta por dos capas convolucionales y 3 capas FullyConnected de Perceptrones Multicapa. Si bien la red original usaba funciones de activacion de tangenge hiperbólica, en nuestro caso se utilizaron funciones ReLu.

# %% [markdown]
# ![image.png](attachment:c5e137cb-fc90-4f00-abe9-fdac2ebe2fbc.png)

# %%
class LeNet5(nn.Module):

    def __init__(self, n_canales_rgb, n_clases, cantidad_filtros_conv, tamaño_filtro_conv, 
                 tamaño_kernel_pooling, stride, padding):
        super().__init__()
        # cantidad de canales y clases, a definir por el diseñador
        self.n_canales_rgb = n_canales_rgb
        self.n_clases = n_clases
        self.tamaño_kernel_pooling = tamaño_kernel_pooling
        # Le net tiene dos capas convolucionales
        self.conv1 = nn.Conv2d(self.n_canales_rgb, cantidad_filtros_conv, kernel_size=tamaño_filtro_conv)
        self.conv2 = nn.Conv2d(cantidad_filtros_conv, 16, kernel_size=tamaño_filtro_conv)
        # y tres capas de MLPs
        self.fc1 = torch.nn.Linear(13456, 120)
        self.fc2 = torch.nn.Linear(120, 84)
        self.fc3 = torch.nn.Linear(84, self.n_clases)

    def forward(self, x):
        # capa convolucional
        x = self.conv1(x)
        # al resultado de la convolucion, le aplica una ReLu
        x = F.relu(x)
        # y luego un pooling
        x = F.max_pool2d(x, (self.tamaño_kernel_pooling, self.tamaño_kernel_pooling))
        
        # Segunda capa convolucional
        x = self.conv2(x)
        # aplica relu
        x = F.relu(x)
        # pooling 
        x = F.max_pool2d(x, (self.tamaño_kernel_pooling, self.tamaño_kernel_pooling))
        
        # flatten de las imagenes para pasarlo a MLPs
        x = torch.flatten(x, 1)
        # MLPs con relus
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        
        return x

# %% [markdown]
# > _Puesto que variaremos los hiperparametros de nuestra red en reiteradas ocaciones, vamos a modularizar el proceso de creación y entrenamiento del modelo a través de una función_

# %%
def crear_model(cantidad_filtros_conv, tamaño_filtro_conv, 
                 tamaño_kernel_pooling, stride, padding):
    # Instanciamos la clase del modelo:
    model = LeNet5(n_canales_rgb = 3, n_clases=4, cantidad_filtros_conv = 6, tamaño_filtro_conv = 5, 
                 tamaño_kernel_pooling = 2, stride = 1, padding = False)
    # CUDA / CPU
    model = model.to('cpu')
    return model

# %%
def entrenar_model(model, optimizer, epocas, batch_size):
    minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
        model=model,
        num_epochs=NUM_EPOCAS,
        train_loader=train_loader,
        valid_loader=valid_loader,
        test_loader=test_loader,
        optimizer=optimizer,
        device='cpu',
        log_interval_batch=5)
    return minibatch_loss_list, train_acc_list, valid_acc_list

# %% [markdown]
# > _La optimización de la red se realizará con el algoritmo del descenso del gradiente estocástico_

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %% [markdown]
# > ## Primer modelo y entrenamiento

# %%
crear_model(6, 5, 2, 1, False)
# Out:
# LeNet5(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=13456, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=4, bias=True)
# )

# %%
NUM_EPOCAS = 3
valid_size = 0.2
batch_size = 1

# %%
entrenar_model(model, optimizer, NUM_EPOCAS, batch_size)
# Out:
# salida prop adelante tensor([[-0.0070,  0.1182, -0.0137, -0.0254]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# Epoca: 001/003 | Batch 0000/5125 | Loss: 1.4131
# salida prop adelante tensor([[-0.0052,  0.1180, -0.0118, -0.0252]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0069,  0.1183, -0.0152, -0.0257]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0043,  0.1178, -0.0143, -0.0267]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0056,  0.1190, -0.0153, -0.0266]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0059,  0.1175, -0.0135, -0.0264]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# Epoca: 001/003 | Batch 0005/5125 | Loss: 1.4118
# salida prop adelante tensor([[-0.0078,  0.1196, -0.0172, -0.0230]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0053,  0.1180, -0.0141, -0.0271]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0069,  0.1195, -0.0133, -0.0253]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0076,  0.1183, -0.0149, -0.0250]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0047,  0.1183, -0.0149, -0.0277]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# Epoca: 001/003 | Batch 0010/5125 | Loss: 1.4105
# salida prop adelante tensor([[-0.0065,  0.1183, -0.0157, -0.0275]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0063,  0.1189, -0.0141, -0.0251]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0051,  0.1179, -0.0163, -0.0258]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0066,  0.1188, -0.0154, -0.0251]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0066,  0.1195, -0.0123, -0.0245]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# Epoca: 001/003 | Batch 0015/5125 | Loss: 1.4137
# salida prop adelante tensor([[-0.0057,  0.1198, -0.0137, -0.0262]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0059,  0.1181, -0.0133, -0.0263]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0054,  0.1176, -0.0164, -0.0258]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0074,  0.1198, -0.0153, -0.0242]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0061,  0.1186, -0.0153, -0.0262]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# Epoca: 001/003 | Batch 0020/5125 | Loss: 1.4119
# salida prop adelante tensor([[-0.0068,  0.1187, -0.0132, -0.0255]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0074,  0.1174, -0.0129, -0.0259]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0054,  0.1191, -0.0148, -0.0246]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0063,  0.1196, -0.0128, -0.0263]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0066,  0.1196, -0.0147, -0.0242]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# Epoca: 001/003 | Batch 0025/5125 | Loss: 1.4132
# salida prop adelante tensor([[-0.0058,  0.1184, -0.0156, -0.0258]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0060,  0.1182, -0.0148, -0.0251]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0045,  0.1195, -0.0154, -0.0271]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0052,  0.1182, -0.0159, -0.0249]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0052,  0.1182, -0.0162, -0.0255]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# Epoca: 001/003 | Batch 0030/5125 | Loss: 1.4111
# salida prop adelante tensor([[-0.0058,  0.1183, -0.0114, -0.0250]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0058,  0.1181, -0.0142, -0.0265]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0039,  0.1179, -0.0140, -0.0268]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0060,  0.1189, -0.0153, -0.0266]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0050,  0.1170, -0.0143, -0.0263]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# Epoca: 001/003 | Batch 0035/5125 | Loss: 1.4109
# salida prop adelante tensor([[-0.0073,  0.1190, -0.0165, -0.0238]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0053,  0.1184, -0.0156, -0.0268]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0070,  0.1191, -0.0138, -0.0257]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0073,  0.1179, -0.0148, -0.0248]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0051,  0.1179, -0.0143, -0.0270]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# Epoca: 001/003 | Batch 0040/5125 | Loss: 1.4110
# salida prop adelante tensor([[-0.0051,  0.1175, -0.0156, -0.0252]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0044,  0.1180, -0.0143, -0.0263]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0068,  0.1186, -0.0158, -0.0248]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0056,  0.1202, -0.0144, -0.0257]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0067,  0.1183, -0.0136, -0.0261]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# Epoca: 001/003 | Batch 0045/5125 | Loss: 1.4127
# salida prop adelante tensor([[-0.0071,  0.1186, -0.0150, -0.0248]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0059,  0.1183, -0.0156, -0.0259]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0072,  0.1186, -0.0138, -0.0250]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0049,  0.1190, -0.0149, -0.0256]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0066,  0.1200, -0.0135, -0.0258]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# Epoca: 001/003 | Batch 0050/5125 | Loss: 1.4132
# salida prop adelante tensor([[-0.0069,  0.1184, -0.0147, -0.0260]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0065,  0.
-0.0277]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# Epoca: 001/003 | Batch 0360/5125 | Loss: 1.4115
# salida prop adelante tensor([[-0.0058,  0.1180, -0.0141, -0.0270]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0054,  0.1182, -0.0156, -0.0280]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0063,  0.1179, -0.0155, -0.0274]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0054,  0.1183, -0.0173, -0.0269]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0051,  0.1181, -0.0168, -0.0274]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# Epoca: 001/003 | Batch 0365/5125 | Loss: 1.4104
# salida prop adelante tensor([[-0.0057,  0.1162, -0.0160, -0.0269]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0056,  0.1157, -0.0173, -0.0275]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0064,  0.1171, -0.0167, -0.0258]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0070,  0.1174, -0.0148, -0.0277]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0064,  0.1185, -0.0162, -0.0265]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# Epoca: 001/003 | Batch 0370/5125 | Loss: 1.4118
# salida prop adelante tensor([[-0.0062,  0.1169, -0.0153, -0.0278]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0059,  0.1162, -0.0159, -0.0272]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0054,  0.1164, -0.0186, -0.0276]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0064,  0.1184, -0.0160, -0.0263]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0064,  0.1188, -0.0157, -0.0275]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# Epoca: 001/003 | Batch 0375/5125 | Loss: 1.4117
# salida prop adelante tensor([[-0.0053,  0.1175, -0.0160, -0.0277]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0048,  0.1172, -0.0155, -0.0285]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0044,  0.1166, -0.0166, -0.0277]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0074,  0.1171, -0.0161, -0.0271]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0069,  0.1161, -0.0144, -0.0280]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# Epoca: 001/003 | Batch 0380/5125 | Loss: 1.4116
# salida prop adelante tensor([[-0.0059,  0.1184, -0.0151, -0.0266]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0060,  0.1169, -0.0156, -0.0273]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0053,  0.1188, -0.0149, -0.0274]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0069,  0.1180, -0.0142, -0.0261]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0065,  0.1182, -0.0130, -0.0267]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# Epoca: 001/003 | Batch 0385/5125 | Loss: 1.4126
# salida prop adelante tensor([[-0.0054,  0.1178, -0.0156, -0.0285]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# salida prop adelante tensor([[-0.0057,  0.1182, -0.0161, -0.0277]], grad_fn=<AddmmBackward0>)
# Targets tensor([0])
# ...
#   1.4111745357513428,
#   1.4124674797058105,
#   1.411354899406433,
#   1.4111698865890503,
#   1.4109809398651123,
#   1.4104688167572021,
#   1.4100513458251953,
#   1.4105738401412964,
#   1.411649465560913,
#   1.4120051860809326,
#   1.4112478494644165,
#   1.4117827415466309,
#   1.4117008447647095,
#   1.411107063293457,
#   1.4095975160598755,
#   1.4106171131134033,
#   1.412033200263977,
#   1.411553144454956,
#   1.4116363525390625,
#   1.4109289646148682,
#   1.4112038612365723,
#   1.4118057489395142,
#   1.412305235862732,
#   1.411370873451233,
#   1.411853551864624,
#   1.4106193780899048,
#   1.4107465744018555,
#   1.4110429286956787,
#   1.4118856191635132,
#   1.4119848012924194,
#   1.410750150680542,
#   1.4120244979858398,
#   1.4111764430999756,
#   1.4101923704147339,
#   1.4108647108078003,
#   1.4115737676620483,
#   1.4118741750717163,
#   1.4119651317596436,
#   1.4115549325942993,
#   1.411239743232727,
#   1.4110372066497803,
#   1.4101511240005493,
#   1.4100924730300903,
#   1.412100076675415,
#   1.4113233089447021,
#   1.4108059406280518,
#   1.4123120307922363,
#   1.4109447002410889,
#   1.412479043006897,
#   1.4118320941925049,
#   1.4101486206054688,
#   1.411956787109375,
#   1.410331130027771,
#   1.4108867645263672,
#   1.4111442565917969,
#   1.409574270248413,
#   1.4106162786483765,
#   1.4116127490997314,
#   1.4127358198165894,
#   1.4110510349273682,
#   1.411062240600586,
#   1.4101195335388184,
#   1.4113222360610962,
#   1.4108015298843384,
#   1.4121265411376953,
#   1.410454273223877,
#   1.413409948348999,
#   1.41368567943573,
#   1.413118600845337,
#   1.4131628274917603,
#   1.2873860597610474,
#   1.2866358757019043,
#   1.2874670028686523,
#   1.286882758140564,
#   1.2869569063186646,
#   1.287116289138794,
#   1.28702974319458,
#   1.2874572277069092,
#   1.2872459888458252,
#   1.2871681451797485,
#   1.2876683473587036,
#   1.287130355834961,
#   1.28718101978302,
#   1.2874641418457031,
#   1.2870488166809082,
#   1.2873897552490234,
#   1.2868797779083252,
#   1.2868458032608032,
#   1.287501335144043,
#   1.2863422632217407,
#   1.2874090671539307,
#   1.286358118057251,
#   1.2870545387268066,
#   1.287193775177002,
#   1.2867032289505005,
#   1.286741852760315,
#   1.2871297597885132,
#   1.2869774103164673,
#   1.2870240211486816,
#   1.2878236770629883,
#   1.287481665611267,
#   1.28799569606781,
#   1.2878226041793823,
#   1.2878129482269287,
#   1.2870231866836548,
#   1.288611650466919,
#   1.2877227067947388,
#   1.2890726327896118,
#   1.288010597229004,
#   1.2890063524246216,
#   1.2887760400772095,
#   1.2884985208511353,
#   1.2888758182525635,
#   1.2876648902893066,
#   1.2871845960617065,
#   1.2884992361068726,
#   1.2870362997055054,
#   1.2880041599273682,
#   1.286673903465271,
#   1.2878351211547852,
#   1.2876386642456055,
#   1.421258568763733,
#   1.4220130443572998,
#   1.4219354391098022,
#   1.4206706285476685,
#   1.42284095287323,
#   1.4207297563552856,
#   1.4222315549850464,
#   1.4211509227752686,
#   1.4199692010879517,
#   1.4210089445114136,
#   1.4208413362503052,
#   1.4209020137786865,
#   1.421777367591858,
#   1.4222344160079956,
#   1.4211490154266357,
#   1.4210485219955444,
#   1.4219037294387817,
#   1.421033263206482,
#   1.4212262630462646,
#   1.422224760055542,
#   1.4200836420059204,
#   1.4213894605636597,
#   1.4205402135849,
#   1.4204398393630981,
#   1.422013282775879,
#   1.4214189052581787,
#   1.4219605922698975,
#   1.4223202466964722,
#   1.422426462173462,
#   1.422534465789795,
#   1.4222254753112793,
#   1.4215679168701172,
#   1.4195914268493652,
#   1.4218662977218628,
#   1.4207044839859009,
#   1.420636534690857,
#   1.4206523895263672,
#   1.4211362600326538,
#   1.419723629951477,
#   1.4215943813323975,
#   1.4204903841018677,
#   1.4211983680725098,
#   1.4223639965057373,
#   1.4205536842346191,
#   1.4198931455612183,
#   1.4208347797393799,
#   1.4213833808898926,
#   1.4215258359909058,
#   1.4197441339492798,
#   1.4208166599273682,
#   1.4229328632354736,
#   1.4227683544158936,
#   1.4229843616485596,
#   1.4211307764053345,
#   1.4210883378982544,
#   1.4222612380981445,
#   1.4218662977218628,
#   1.4224430322647095,
#   1.4222123622894287,
#   1.4219740629196167,
#   1.4228500127792358,
#   1.4205220937728882,
#   1.4209752082824707,
#   1.4221718311309814,
#   1.422369360923767,
#   1.4189497232437134,
#   1.4208887815475464,
#   1.420721411705017,
#   1.4210150241851807,
#   1.4194213151931763,
#   1.4212069511413574,
#   1.420619249343872,
#   1.4213041067123413,
#   1.4200472831726074,
#   1.4201440811157227,
#   1.4214586019515991,
#   1.4216443300247192,
#   1.421825885772705,
#   1.4208959341049194,
#   1.4207448959350586,
#   1.4215798377990723,
#   1.4196891784667969,
#   1.4214316606521606,
#   1.4229944944381714,
#   1.4209692478179932,
#   1.4223140478134155,
#   1.42301607131958,
#   1.4206440448760986,
#   1.4218207597732544,
#   1.4203274250030518,
#   1.4208823442459106,
#   1.4202985763549805,
#   1.419618010520935,
#   1.4206629991531372,
#   1.4203605651855469,
#   1.4201961755752563,
#   1.4213823080062866,
#   1.4209457635879517,
#   1.4205090999603271,
#   1.4200092554092407,
#   ...],
#  [0.9951220154762268, 0.9951220154762268, 0.9951220154762268],
#  [0.9389671683311462, 0.9389671683311462, 0.9389671683311462])

# %%
plot_training_loss(minibatch_loss_list = minibatch_loss_list,
                   num_epochs = NUM_EPOCAS,
                   iter_per_epoch = len(train_loader),
                   averaging_iterations = 100)
plt.show()

plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list)
plt.ylim([80, 100])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <module>
# ----> 1 plot_training_loss(minibatch_loss_list = minibatch_loss_list,
#       2                    num_epochs = NUM_EPOCAS,
#       3                    iter_per_epoch = len(train_loader),
#       4                    averaging_iterations = 100)
#       5 plt.show()
#       7 plot_accuracy(train_acc_list=train_acc_list,
#       8               valid_acc_list=valid_acc_list)
#
# NameError: name 'minibatch_loss_list' is not defined

# %% [markdown]
# > ## Ejercicio 1: Variación de Hiperparámetros

# %% [markdown]
# **A) Modificar la cantidad de canales (filtros) de la capa convolucional, el tamaño del kernel de convolución y el tamaño del kernel de pooling.**
#
# Sabemos que existe una relación de dimensiones entre el tamaño del kernel de convolución, la cantidad de filtros y el tamaño del kernel de pooling. En la siguiente imágen podemos observar como se relacionan estos parámetros:
# [imagene de la red con las dimensines]

# %% [markdown]
# **B) Incorporar padding y stride distintos a los valores por defecto. Explicar en qué consisten estos conceptos**

# %% [markdown]
# **C) Dibujar la curva de la función costo en función de los pasos de entrenamiento. Variar el valor de la constante de aprendizaje (learning rate) y comentar si se observan diferencias en el comportamiento de la curva**

# %% [markdown]
# **D) Cambiar el parámetro _batch_size_ y explicar por qué varía la cantidad de pasos en el entrenamiento al modificarlo**

# %% [markdown]
# **E) Aumentar la cantidad de _epocs_. Observar cómo se comportan las curvas de aprendizaje**

# %% [markdown]
# **F) Agregar una capa convolucional, una capa de max pooling y una capa lineal de manera tal que la red siga funcionando. Explicar la elección de dimensiones para que la red sea funcional.**

# %% [markdown]
# **G) Reemplazar la red convolucional por un perceptrón multicapa. Variar la cantidad de capass y neuronaes y comprar los resultados**

# %% [markdown]
# > ## Ejercicio 2: Regularización

# %% [markdown]
# **A) Implementar _dropout_ y _penalidad L2_. Explicar ambos conceptos**

# %% [markdown]
# > ## Ejercicio 3: Validación

# %% [markdown]
# **A) Armar un set de validación separando parte del set de entrenamiento.**

# %% [markdown]
# **B) Implementar _early stopping_. Explicar para que sirve**
